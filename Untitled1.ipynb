# %%
! pip install selenium

# %%
from selenium import webdriver  
from time import sleep

# %%
driver = webdriver.Chrome("C:/Users/User/chromedriver_win32/chromedriver")

# %%
driver.get("https://www.lawplus.com.tw/")

# %%
driver.find_element("xpath","//a[@href='#searchReport']").click()

# %%
driver.find_element("xpath","//input[@type='text']").send_keys("內線交易\n")

# %%
driver.find_element("xpath","//li[@class='result']/h4/a").click()

# %%
a = driver.find_element("xpath","//li[@class='result']/h4/a").text

# %%
a = {}
a["code"] = driver.find_element("xpath","//div[@class='reportInfo nine columns']/h5").text
a["date"] = driver.find_element("xpath","//div[@class='reportInfo nine columns']/p").text
a["content"] = driver.find_element("xpath","//*[@id='reportBase']").text

# %%
a
# Out:
# {'code': '96,訴,42',
#  'date': '2007/06/25',
# ...

# %%
driver.back()

# %%
a["code"] = driver.find_element("xpath","//div[@class='reportInfo nine columns']/h5").text
